# %% [markdown]
# testing from https://open-meteo.com/en/docs/marine-weather-api

# %%
# Cell 1: Install required package (if needed)
# !pip install requests matplotlib --quiet
# Out:
# WARNING: You are using pip version 21.1.1; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\users\chris\desktop\school\24-25\spring\ece 140b\surfwatch\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Cell 2: Import libraries
import requests
import matplotlib.pyplot as plt
import json
from datetime import datetime

# %%
# HOLIDAY API
# switch SchoolHolidays --> PublicHolidays to show all holidays
# # Define the base URL
url = 'https://openholidaysapi.org/SchoolHolidays'

# Set up parameters
params = {
    'countryIsoCode': 'DE',  # ISO 3166-1 alpha-2 country code (e.g., 'DE' for Germany)
    'languageIsoCode': 'en',  # ISO 639-1 language code (e.g., 'en' for English)
    'validFrom': '2025-01-01',
    'validTo': '2025-12-31'
}

# Make the GET request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    holidays = response.json()
    for holiday in holidays:
        print(f"{holiday['startDate']}: {holiday['name']}")
else:
    print(f"Error: {response.status_code}")
# Out:
# 2024-12-19: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-20: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2024-12-23: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-01-27: [{'language': 'EN', 'text': 'Winter Holidays'}]
# 2025-01-31: [{'language': 'EN', 'text': 'Mid-Year Break'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Winter Holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Mid-Year Holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Winter Holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Winter holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Winter holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Winter Holidays'}]
# 2025-02-03: [{'language': 'EN', 'text': 'Mid-Year Holidays'}]
# 2025-02-17: [{'language': 'EN', 'text': 'Winter Holidays'}]
# 2025-02-24: [{'language': 'EN', 'text': 'Carnival Holidays'}]
# 2025-03-03: [{'language': 'EN', 'text': 'Spring Holidays'}]
# 2025-03-10: [{'language': 'EN', 'text': 'Spring Holidays'}]
# 2025-04-07: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-07: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-07: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-07: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-07: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-11: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-14: [{'language': 'EN', 'text': 'Easter holidays'}]
# 2025-04-18: [{'language': 'EN', 'text': 'Easter Holidays'}]
# 2025-04-30: [{'language': 'EN', 'text': 'Church Day and the Day after 1 May'}]
# 2025-04-30: [{'language': 'EN', 'text': 'Church Day'}]
# 2025-05-02: [{'language': 'EN', 'text': 'Day after 1 May'}]
# 2025-05-02: [{'language': 'EN', 'text': 'Variable holiday'}]
# 2025-05-02: [{'language': 'EN', 'text': 'Day off'}]
# 2025-05-02: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-05-02: [{'language': 'EN', 'text': 'Bridge Day'}]
# 2025-05-26: [{'language': 'EN', 'text': 'Pentecost Holidays'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Ascension'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Day after Ascension'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Day after Ascension'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Variable holiday'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Day off from school'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Day off'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Holiday Day'}]
# 2025-05-30: [{'language': 'EN', 'text': 'Day off'}]
# 2025-06-06: [{'language': 'EN', 'text': 'Pentecost Holidays'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost holiday'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost Holiday'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost Holidays'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost Holidays'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost Holiday'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost Holidays'}]
# 2025-06-10: [{'language': 'EN', 'text': 'Pentecost holiday'}]
# 2025-06-28: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-06-28: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-06-28: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-03: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-03: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-07: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-07: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-07: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-14: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-14: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-24: [{'language': 'EN', 'text': 'Summer holidays'}]
# 2025-07-24: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-24: [{'language': 'EN', 'text': 'Summer holidays'}]
# 2025-07-28: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-28: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-07-31: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-08-01: [{'language': 'EN', 'text': 'Summer Holidays'}]
# 2025-10-01: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-10-02: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-10-06: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-06: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-06: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-13: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-20: [{'language': 'EN', 'text': 'Autumn holidays'}]
# 2025-10-20: [{'language': 'EN', 'text': 'Autumn holidays'}]
# 2025-10-20: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-20: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-20: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-10-27: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-11-03: [{'language': 'EN', 'text': 'Autumn Holidays'}]
# 2025-11-03: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-11-03: [{'language': 'EN', 'text': 'Additional holiday'}]
# 2025-11-19: [{'language': 'EN', 'text': 'Repentance Day'}]
# 2025-12-17: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-19: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]
# 2025-12-22: [{'language': 'EN', 'text': 'Christmas Holidays'}]

# %%
# CURRENT WEATHER API
# 100 requests per month for free
WEATHER_API_KEY = "d7496cda100e067cdb9df69d599f6c45"
url = "http://api.weatherstack.com/current"

params = {
    "access_key": WEATHER_API_KEY,
    # "query": "32.7, -117.2",
    # "query": "Berlin, Germany",
    "query": "La Jolla, California, USA",
}

response = requests.get(url, params=params)
data = response.json()

print(json.dumps(data, indent=2))
# Out:
# {
#   "request": {
#     "type": "City",
#     "query": "La Jolla, United States of America",
#     "language": "en",
#     "unit": "m"
#   },
#   "location": {
#     "name": "La Jolla",
#     "country": "United States of America",
#     "region": "California",
#     "lat": "32.847",
#     "lon": "-117.273",
#     "timezone_id": "America/Los_Angeles",
#     "localtime": "2025-05-27 19:54",
#     "localtime_epoch": 1748375640,
#     "utc_offset": "-7.0"
#   },
#   "current": {
#     "observation_time": "02:54 AM",
#     "temperature": 17,
#     "weather_code": 122,
#     "weather_icons": [
#       "https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"
#     ],
#     "weather_descriptions": [
#       "Overcast"
#     ],
#     "astro": {
#       "sunrise": "05:43 AM",
#       "sunset": "07:49 PM",
#       "moonrise": "05:51 AM",
#       "moonset": "09:08 PM",
#       "moon_phase": "New Moon",
#       "moon_illumination": 0
#     },
#     "air_quality": {
#       "co": "366.3",
#       "no2": "69.93",
#       "o3": "29",
#       "so2": "6.66",
#       "pm2_5": "33.115",
#       "pm10": "41.625",
#       "us-epa-index": "2",
#       "gb-defra-index": "2"
#     },
#     "wind_speed": 12,
#     "wind_degree": 238,
#     "wind_dir": "WSW",
#     "pressure": 1015,
#     "precip": 0,
#     "humidity": 75,
#     "cloudcover": 100,
#     "feelslike": 17,
#     "uv_index": 0,
#     "visibility": 16,
#     "is_day": "no"
#   }
# }

# %%
# HISTORIAL WEATHER API
WEATHER_API_KEY = "d7496cda100e067cdb9df69d599f6c45"
url = "http://api.weatherstack.com/historical"

params = {
    "access_key": WEATHER_API_KEY,
    "query": "32.7, -117.2",
    "historical_date": "2025-20-05",
}

response = requests.get(url, params=params)
data = response.json()

print(json.dumps(data, indent=2))
# Out:
# {
#   "success": false,
#   "error": {
#     "code": 603,
#     "type": "historical_queries_not_supported_on_plan",
#     "info": "Your current subscription plan does not support historical weather data. Please upgrade your account to use this feature."
#   }
# }

# %%
# Cell 3: Set up the API request
url = "https://marine-api.open-meteo.com/v1/marine"

params = {
    "latitude": 32.7,
    "longitude": -117.2,
    # "past_days": 90,
    "hourly": ["wave_height", "sea_surface_temperature"],  # Use a list instead of comma-separated string
    # "forecast_days": 4,
    "timezone": "America/Los_Angeles"
}

response = requests.get(url, params=params)
data = response.json()
# Extract and convert sea surface temperatures
temps_celsius = data["hourly"]["sea_surface_temperature"]
temps_fahrenheit = [(temp * 9/5) + 32 for temp in temps_celsius]

# Replace original data or print some examples
print("Sample Sea Surface Temperatures (°F):")
for i in range(24):  # Show first 5 entries
    print(f"{data['hourly']['time'][i]}: {temps_fahrenheit[i]:.2f} °F")
    
print(json.dumps(data, indent=2))
# Out:
# Sample Sea Surface Temperatures (°F):
# 2025-05-22T00:00: 64.76 °F
# 2025-05-22T01:00: 64.76 °F
# 2025-05-22T02:00: 64.58 °F
# 2025-05-22T03:00: 64.40 °F
# 2025-05-22T04:00: 64.40 °F
# 2025-05-22T05:00: 64.40 °F
# 2025-05-22T06:00: 64.40 °F
# 2025-05-22T07:00: 64.40 °F
# 2025-05-22T08:00: 64.58 °F
# 2025-05-22T09:00: 64.58 °F
# 2025-05-22T10:00: 64.76 °F
# 2025-05-22T11:00: 65.12 °F
# 2025-05-22T12:00: 65.30 °F
# 2025-05-22T13:00: 65.48 °F
# 2025-05-22T14:00: 65.84 °F
# 2025-05-22T15:00: 66.02 °F
# 2025-05-22T16:00: 66.20 °F
# 2025-05-22T17:00: 66.20 °F
# 2025-05-22T18:00: 66.20 °F
# 2025-05-22T19:00: 66.20 °F
# 2025-05-22T20:00: 66.02 °F
# 2025-05-22T21:00: 65.84 °F
# 2025-05-22T22:00: 65.66 °F
# 2025-05-22T23:00: 65.48 °F
# {
#   "latitude": 32.708336,
#   "longitude": -117.20833,
#   "generationtime_ms": 0.042319297790527344,
#   "utc_offset_seconds": -25200,
#   "timezone": "America/Los_Angeles",
#   "timezone_abbreviation": "GMT-7",
#   "elevation": 0.0,
#   "hourly_units": {
#     "time": "iso8601",
#     "wave_height": "m",
#     "sea_surface_temperature": "\u00b0C"
#   },
#   "hourly": {
#     "time": [
#       "2025-05-22T00:00",
#       "2025-05-22T01:00",
#       "2025-05-22T02:00",
#       "2025-05-22T03:00",
#       "2025-05-22T04:00",
#       "2025-05-22T05:00",
#       "2025-05-22T06:00",
#       "2025-05-22T07:00",
#       "2025-05-22T08:00",
#       "2025-05-22T09:00",
#       "2025-05-22T10:00",
#       "2025-05-22T11:00",
#       "2025-05-22T12:00",
#       "2025-05-22T13:00",
#       "2025-05-22T14:00",
#       "2025-05-22T15:00",
#       "2025-05-22T16:00",
#       "2025-05-22T17:00",
#       "2025-05-22T18:00",
#       "2025-05-22T19:00",
#       "2025-05-22T20:00",
#       "2025-05-22T21:00",
#       "2025-05-22T22:00",
#       "2025-05-22T23:00",
#       "2025-05-23T00:00",
#       "2025-05-23T01:00",
#       "2025-05-23T02:00",
#       "2025-05-23T03:00",
#       "2025-05-23T04:00",
#       "2025-05-23T05:00",
#       "2025-05-23T06:00",
#       "2025-05-23T07:00",
#       "2025-05-23T08:00",
#       "2025-05-23T09:00",
#       "2025-05-23T10:00",
#       "2025-05-23T11:00",
#       "2025-05-23T12:00",
#       "2025-05-23T13:00",
#       "2025-05-23T14:00",
#       "2025-05-23T15:00",
#       "2025-05-23T16:00",
#       "2025-05-23T17:00",
#       "2025-05-23T18:00",
#       "2025-05-23T19:00",
#       "2025-05-23T20:00",
#       "2025-05-23T21:00",
#       "2025-05-23T22:00",
#       "2025-05-23T23:00",
#       "2025-05-24T00:00",
#       "2025-05-24T01:00",
#       "2025-05-24T02:00",
#       "2025-05-24T03:00",
#       "2025-05-24T04:00",
#       "2025-05-24T05:00",
#       "2025-05-24T06:00",
#       "2025-05-24T07:00",
#       "2025-05-24T08:00",
#       "2025-05-24T09:00",
#       "2025-05-24T10:00",
#       "2025-05-24T11:00",
#       "2025-05-24T12:00",
#       "2025-05-24T13:00",
#       "2025-05-24T14:00",
#       "2025-05-24T15:00",
#       "2025-05-24T16:00",
#       "2025-05-24T17:00",
#       "2025-05-24T18:00",
#       "2025-05-24T19:00",
#       "2025-05-24T20:00",
#       "2025-05-24T21:00",
#       "2025-05-24T22:00",
#       "2025-05-24T23:00",
#       "2025-05-25T00:00",
#       "2025-05-25T01:00",
#       "2025-05-25T02:00",
#       "2025-05-25T03:00",
#       "2025-05-25T04:00",
#       "2025-05-25T05:00",
#       "2025-05-25T06:00",
#       "2025-05-25T07:00",
#       "2025-05-25T08:00",
#       "2025-05-25T09:00",
#       "2025-05-25T10:00",
#       "2025-05-25T11:00",
#       "2025-05-25T12:00",
#       "2025-05-25T13:00",
#       "2025-05-25T14:00",
#       "2025-05-25T15:00",
#       "2025-05-25T16:00",
#       "2025-05-25T17:00",
#       "2025-05-25T18:00",
#       "2025-05-25T19:00",
#       "2025-05-25T20:00",
#       "2025-05-25T21:00",
#       "2025-05-25T22:00",
#       "2025-05-25T23:00",
#       "2025-05-26T00:00",
#       "2025-05-26T01:00",
#       "2025-05-26T02:00",
#       "2025-05-26T03:00",
#       "2025-05-26T04:00",
#       "2025-05-26T05:00",
#       "2025-05-26T06:00",
#       "2025-05-26T07:00",
#       "2025-05-26T08:00",
#       "2025-05-26T09:00",
#       "2025-05-26T10:00",
#       "2025-05-26T11:00",
#       "2025-05-26T12:00",
#       "2025-05-26T13:00",
#       "2025-05-26T14:00",
#       "2025-05-26T15:00",
#       "2025-05-26T16:00",
#       "2025-05-26T17:00",
#       "2025-05-26T18:00",
#       "2025-05-26T19:00",
#       "2025-05-26T20:00",
#       "2025-05-26T21:00",
#       "2025-05-26T22:00",
#       "2025-05-26T23:00",
#       "2025-05-27T00:00",
#       "2025-05-27T01:00",
#       "2025-05-27T02:00",
#       "2025-05-27T03:00",
#       "2025-05-27T04:00",
#       "2025-05-27T05:00",
#       "2025-05-27T06:00",
#       "2025-05-27T07:00",
#       "2025-05-27T08:00",
#       "2025-05-27T09:00",
#       "2025-05-27T10:00",
#       "2025-05-27T11:00",
#       "2025-05-27T12:00",
#       "2025-05-27T13:00",
#       "2025-05-27T14:00",
#       "2025-05-27T15:00",
#       "2025-05-27T16:00",
#       "2025-05-27T17:00",
#       "2025-05-27T18:00",
#       "2025-05-27T19:00",
#       "2025-05-27T20:00",
#       "2025-05-27T21:00",
#       "2025-05-27T22:00",
#       "2025-05-27T23:00",
#       "2025-05-28T00:00",
#       "2025-05-28T01:00",
#       "2025-05-28T02:00",
#       "2025-05-28T03:00",
#       "2025-05-28T04:00",
#       "2025-05-28T05:00",
#       "2025-05-28T06:00",
#       "2025-05-28T07:00",
#       "2025-05-28T08:00",
#       "2025-05-28T09:00",
#       "2025-05-28T10:00",
#       "2025-05-28T11:00",
#       "2025-05-28T12:00",
#       "2025-05-28T13:00",
#       "2025-05-28T14:00",
#       "2025-05-28T15:00",
#       "2025-05-28T16:00",
#       "2025-05-28T17:00",
#       "2025-05-28T18:00",
#       "2025-05-28T19:00",
#       "2025-05-28T20:00",
#       "2025-05-28T21:00",
#       "2025-05-28T22:00",
#       "2025-05-28T23:00"
#     ],
#     "wave_height": [
#       1.0,
#       0.98,
#       0.98,
#       0.98,
#       0.96,
#       0.96,
#       0.96,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.94,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.96,
#       0.98,
#       0.98,
#       1.0,
#       1.0,
#       1.02,
#       1.06,
#       1.12,
#       1.16,
#       1.2,
#       1.22,
#       1.26,
#       1.28,
#       1.32,
#       1.34,
#       1.36,
#       1.36,
#       1.38,
#       1.4,
#       1.42,
#       1.44,
#       1.46,
#       1.48,
#       1.5,
#       1.5,
#       1.5,
#       1.5,
#       1.5,
#       1.48,
#       1.48,
#       1.48,
#       1.46,
#       1.46,
#       1.46,
#       1.48,
#       1.48,
#       1.5,
#       1.5,
#       1.52,
#       1.5,
#       1.5,
#       1.48,
#       1.46,
#       1.44,
#       1.42,
#       1.4,
#       1.4,
#       1.38,
#       1.38,
#       1.36,
#       1.36,
#       1.34,
#       1.34,
#       1.32,
#       1.32,
#       1.3,
#       1.3,
#       1.3,
#       1.28,
#       1.28,
#       1.28,
#       1.28,
#       1.28,
#       1.28,
#       1.26,
#       1.26,
#       1.26,
#       1.26,
#       1.26,
#       1.26,
#       1.28,
#       1.28,
#       1.28,
#       1.26,
#       1.26,
#       1.26,
#       1.28,
#       1.28,
#       1.28,
#       1.3,
#       1.3,
#       1.3,
#       1.32,
#       1.32,
#       1.32,
#       1.32,
#       1.32,
#       1.3,
#       1.28,
#       1.26,
#       1.24,
#       1.24,
#       1.22,
#       1.24,
#       1.28,
#       1.3,
#       1.34,
#       1.36,
#       1.4,
#       1.42,
#       1.42,
#       1.44,
#       1.46,
#       1.48,
#       1.5,
#       1.52,
#       1.52,
#       1.54,
#       1.52,
#       1.52,
#       1.5,
#       1.48,
#       1.46,
#       1.44,
#       1.42,
#       1.42,
#       1.4,
#       1.4,
#       1.4,
#       1.4,
#       1.38,
#       1.38,
#       1.36,
#       1.36,
#       1.34,
#       1.34,
#       1.32,
#       1.32,
#       1.3,
#       1.28,
#       1.26,
#       1.24,
#       1.22,
#       1.2,
#       1.18,
#       1.18,
#       1.18,
#       1.18,
#       1.2,
#       1.24,
#       1.26,
#       1.28,
#       1.28,
#       1.3
#     ],
#     "sea_surface_temperature": [
#       18.2,
#       18.2,
#       18.1,
#       18.0,
#       18.0,
#       18.0,
#       18.0,
#       18.0,
#       18.1,
#       18.1,
#       18.2,
#       18.4,
#       18.5,
#       18.6,
#       18.8,
#       18.9,
#       19.0,
#       19.0,
#       19.0,
#       19.0,
#       18.9,
#       18.8,
#       18.7,
#       18.6,
#       18.5,
#       18.5,
#       18.4,
#       18.3,
#       18.2,
#       18.2,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.2,
#       18.2,
#       18.4,
#       18.4,
#       18.5,
#       18.5,
#       18.6,
#       18.6,
#       18.5,
#       18.5,
#       18.5,
#       18.4,
#       18.4,
#       18.3,
#       18.2,
#       18.2,
#       18.2,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.1,
#       18.2,
#       18.3,
#       18.4,
#       18.5,
#       18.6,
#       18.8,
#       18.8,
#       18.8,
#       18.8,
#       18.8,
#       18.6,
#       18.6,
#       18.5,
#       18.5,
#       18.5,
#       18.4,
#       18.4,
#       18.3,
#       18.3,
#       18.3,
#       18.4,
#       18.4,
#       18.5,
#       18.5,
#       18.5,
#       18.6,
#       18.7,
#       18.8,
#       18.9,
#       18.9,
#       19.0,
#       19.0,
#       18.9,
#       18.9,
#       18.8,
#       18.7,
#       18.6,
#       18.6,
#       18.5,
#       18.5,
#       18.4,
#       18.4,
#       18.4,
#       18.4,
#       18.4,
#       18.5,
#       18.5,
#       18.6,
#       18.6,
#       18.8,
#       18.9,
#       19.0,
#       19.0,
#       19.1,
#       19.1,
#       19.1,
#       19.1,
#       19.0,
#       18.9,
#       18.8,
#       18.8,
#       18.7,
#       18.6,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.5,
#       18.6,
#       18.7,
#       18.9,
#       19.0,
#       19.2,
#       19.4,
#       19.4,
#       19.4,
#       19.4,
#       19.2,
#       19.1,
#       19.0,
#       19.0,
#       18.9,
#       18.8,
#       18.8,
#       18.6,
#       18.6,
#       18.6,
#       18.6,
#       18.6,
#       18.7,
#       18.8,
#       18.8,
#       18.9,
#       18.9,
#       19.0,
#       19.1,
#       19.2,
#       19.2,
#       19.3,
#       19.3,
#       19.2,
#       19.2,
#       19.1,
#       19.1,
#       19.0
#     ]
#   }
# }

# %%
STORM_API_KEY="f825b484-368f-11f0-b9ed-0242ac130003-f825b4e8-368f-11f0-b9ed-0242ac130003"
import arrow
import requests

# Get first hour of today
start = arrow.now().floor('day')

# Get last hour of today
end = arrow.now().ceil('day')

response = requests.get(
  'https://api.stormglass.io/v2/weather/point',
  params={
    'lat': 32.7157,
    'lng': 117.1611,
    'params': ','.join(['waveHeight', 'airTemperature']),
    'start': start.to('UTC').timestamp(),  # Convert to UTC timestamp
    'end': end.to('UTC').timestamp()  # Convert to UTC timestamp
  },
  headers={
    'Authorization': STORM_API_KEY
  }
)

# Do something with response data.
json_data = response.json()
print(json.dumps(json_data, indent=2))
# Out:
# {
#   "hours": [
#     {
#       "airTemperature": {
#         "ecmwf": 34.35,
#         "noaa": 34.68,
#         "sg": 34.35
#       },
#       "time": "2025-05-21T07:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 34.46,
#         "noaa": 34.83,
#         "sg": 34.46
#       },
#       "time": "2025-05-21T08:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 34.56,
#         "noaa": 34.98,
#         "sg": 34.56
#       },
#       "time": "2025-05-21T09:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 33.18,
#         "noaa": 33.39,
#         "sg": 33.18
#       },
#       "time": "2025-05-21T10:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 31.8,
#         "noaa": 31.8,
#         "sg": 31.8
#       },
#       "time": "2025-05-21T11:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 30.42,
#         "noaa": 30.21,
#         "sg": 30.42
#       },
#       "time": "2025-05-21T12:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 29.51,
#         "noaa": 29.52,
#         "sg": 29.51
#       },
#       "time": "2025-05-21T13:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 28.61,
#         "noaa": 28.83,
#         "sg": 28.61
#       },
#       "time": "2025-05-21T14:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 27.7,
#         "noaa": 28.13,
#         "sg": 27.7
#       },
#       "time": "2025-05-21T15:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 26.88,
#         "noaa": 27.75,
#         "sg": 26.88
#       },
#       "time": "2025-05-21T16:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 26.06,
#         "noaa": 27.36,
#         "sg": 26.06
#       },
#       "time": "2025-05-21T17:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 25.24,
#         "noaa": 26.97,
#         "sg": 25.24
#       },
#       "time": "2025-05-21T18:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 24.75,
#         "noaa": 26.48,
#         "sg": 24.75
#       },
#       "time": "2025-05-21T19:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 24.26,
#         "noaa": 25.98,
#         "sg": 24.26
#       },
#       "time": "2025-05-21T20:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 23.77,
#         "noaa": 25.49,
#         "sg": 23.77
#       },
#       "time": "2025-05-21T21:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 25.28,
#         "noaa": 26.91,
#         "sg": 25.28
#       },
#       "time": "2025-05-21T22:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 26.78,
#         "noaa": 28.33,
#         "sg": 26.78
#       },
#       "time": "2025-05-21T23:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 28.29,
#         "noaa": 29.75,
#         "sg": 28.29
#       },
#       "time": "2025-05-22T00:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 29.66,
#         "noaa": 31.32,
#         "sg": 29.66
#       },
#       "time": "2025-05-22T01:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 31.04,
#         "noaa": 32.9,
#         "sg": 31.04
#       },
#       "time": "2025-05-22T02:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 32.41,
#         "noaa": 34.47,
#         "sg": 32.41
#       },
#       "time": "2025-05-22T03:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 32.66,
#         "noaa": 35.04,
#         "sg": 32.66
#       },
#       "time": "2025-05-22T04:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 32.91,
#         "noaa": 35.61,
#         "sg": 32.91
#       },
#       "time": "2025-05-22T05:00:00+00:00"
#     },
#     {
#       "airTemperature": {
#         "ecmwf": 33.16,
#         "noaa": 36.18,
#         "sg": 33.16
#       },
#       "time": "2025-05-22T06:00:00+00:00"
#     }
#   ],
#   "meta": {
#     "cost": 1,
#     "dailyQuota": 10,
#     "end": "2025-05-22 06:00",
#     "lat": 32.7157,
#     "lng": 117.1611,
#     "params": [
#       "waveHeight",
#       "airTemperature"
#     ],
#     "requestCount": 2,
#     "start": "2025-05-21 07:00"
#   }
# }

# %%
if "hourly" not in data:
    print("❌ API did not return hourly data:")
    print(json.dumps(data, indent=2))
else:
    times = [datetime.fromisoformat(t) for t in data["hourly"]["time"]]
    wave_height = data["hourly"]["wave_height"]
    sea_surface_temperature = data["hourly"]["sea_surface_temperature"]
    print("✅ Data loaded successfully.")
# Out:
# ✅ Data loaded successfully.

# %%
# Cell 5: Plot wave height
plt.figure(figsize=(12, 4))
plt.plot(times, wave_height, label="Wave Height (m)", color='blue')
plt.title("Hourly Wave Height Forecast - San Diego")
plt.xlabel("Time")
plt.ylabel("Wave Height (m)")
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Cell 6: Plot Sea Surface Temperature
plt.figure(figsize=(12, 4))
plt.plot(times, sea_surface_temperature, label="Sea Surface Temperature (C)", color='green')
plt.title("Sea Surface Temperature - San Diego")
plt.xlabel("Time")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
